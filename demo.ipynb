# %%
from matplotlib import pyplot as plt

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.scatter([5,6,5,3,4],[2,5,6,7,8])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot([1,5],[2,8])

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.scatter([5,6,5,3,4],[2,5,6,7,8])
plt.plot([1,5],[2,8])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\srija\\anaconda3\\envs\\TF\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.scatter([5,6,5,3,4],[2,5,6,7,8])
plt.plot([1,5],[2,8])
op = plt.show

# %%
op
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
print(op)
# Out:
# <function show at 0x0000019D189CF4C8>

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.scatter([5,6,5,3,4],[2,5,6,7,8])
plt.plot([1,5],[2,8])
print(plt.show)
# Out:
# <function show at 0x0000019D189CF4C8>
